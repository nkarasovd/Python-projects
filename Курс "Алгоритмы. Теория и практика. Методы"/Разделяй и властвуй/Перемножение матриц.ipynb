# %% [markdown]
# # Алгоритм Штрассена

# %% [markdown]
# Будем рассматривать квадратные матрицы размера $n \times n$.
#
# Наивный алгоритм (по определению) работает за время $O(n^3)$.

# %%
from IPython.display import Image
Image(filename='images/Перемножение матриц/matrix_1.png')

# %% [markdown]
# ## Умножение матриц размера $2 \times 2$

# %%
Image(filename='images/Перемножение матриц/matrix_2.png')

# %% [markdown]
# Данная формула верна и в случае, когда $X$ и $Y$ - это матрицы размера $n \times n$, а $X_{ij}$, $Y_{ij}$ - это их подматрицы размера $n/2 \times n/2$.

# %% [markdown]
# ## Визуальное пояснение

# %%
Image(filename='images/Перемножение матриц/matrix_3.png')

# %% [markdown]
# Таким образом получили рекурсивный алгоритм со временем работы $O(n^3)$.

# %%
Image(filename='images/Перемножение матриц/matrix_4.png')

# %% [markdown]
# ## Алгоритм Штрассена

# %%
Image(filename='images/Перемножение матриц/matrix_5.png')

# %% [markdown]
# Теперь вместо 8 рекурсивных вызовов, нужно сделать 7.
#
# __Лемма__. Время работы алгоритма Штрассена есть $O(n^{\log _27}) = O(n^{2.807\ldots})$.
